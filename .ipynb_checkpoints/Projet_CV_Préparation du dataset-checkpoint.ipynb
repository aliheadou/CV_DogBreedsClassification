# %% [markdown]
# # Projet CV : Classification de races de chiens

# %%
# Import libraries
import os, shutil, time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import tqdm

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Préparation des données

# %% [markdown]
# ## 1.1 Présentation

# %%
# Define path to data
annotations_dir = '../Data/ORIG/annotation/Annotation/' 
images_dir = '../Data/ORIG/images/Images/'

# %%
# Count the number of classes (dogs breeds)
breed_names = os.listdir(images_dir)
print("Number of breeds in dataset:", (len(breed_names)))
# Out:
# Number of breeds in dataset: 120

# %%
# Count number of pictures for each breed
df_breeds = pd.DataFrame(index=breed_names,
                         data=[len(os.listdir(images_dir + breed_name)) for breed_name in breed_names],
                         columns=["num_pictures"])

# %%
df_breeds = df_breeds.sort_values(by=['num_pictures'], ascending=False)
df_breeds.T
# Out:
#               Maltese_dog  Afghan_hound  Scottish_deerhound  Pomeranian  \
# num_pictures          252           239                 232         219
#
#               Bernese_mountain_dog  Samoyed  Irish_wolfhound  Shih  \
# num_pictures                   218      218              218   214
#
#               Great_Pyrenees  Leonberg  ...  groenendael  Eskimo_dog  kuvasz  \
# num_pictures             213       210  ...          150         150     150
#
#               clumber  golden_retriever  malinois  Border_collie  \
# num_pictures      150               150       150            150
#
#               Irish_water_spaniel  Pekinese  redbone
# num_pictures                  150       149      148
#
# [1 rows x 120 columns]

# %%
breed_names = list(df_breeds.index)
breed_names
# Out:
# ['Maltese_dog',
#  'Afghan_hound',
#  'Scottish_deerhound',
#  'Pomeranian',
#  'Bernese_mountain_dog',
#  'Samoyed',
#  'Irish_wolfhound',
#  'Shih',
#  'Great_Pyrenees',
#  'Leonberg',
#  'basenji',
#  'Tibetan_terrier',
#  'Airedale',
#  'EntleBucher',
#  'Sealyham_terrier',
#  'pug',
#  'Saluki',
#  'Lakeland_terrier',
#  'cairn',
#  'chow',
#  'Australian_terrier',
#  'Norwegian_elkhound',
#  'papillon',
#  'Newfoundland',
#  'beagle',
#  'Siberian_husky',
#  'Ibizan_hound',
#  'Blenheim_spaniel',
#  'whippet',
#  'bloodhound',
#  'Lhasa',
#  'Japanese_spaniel',
#  'Norwich_terrier',
#  'miniature_pinscher',
#  'silky_terrier',
#  'Boston_bull',
#  'Italian_greyhound',
#  'Bedlington_terrier',
#  'Pembroke',
#  'Dandie_Dinmont',
#  'Kerry_blue_terrier',
#  'malamute',
#  'basset',
#  'toy_terrier',
#  'Border_terrier',
#  'Norfolk_terrier',
#  'Rhodesian_ridgeback',
#  'bluetick',
#  'Labrador_retriever',
#  'Saint_Bernard',
#  'African_hunting_dog',
#  'West_Highland_white_terrier',
#  'Old_English_sheepdog',
#  'Irish_terrier',
#  'Greater_Swiss_Mountain_dog',
#  'Chesapeake_Bay_retriever',
#  'Yorkshire_terrier',
#  'American_Staffordshire_terrier',
#  'English_setter',
#  'Weimaraner',
#  'English_springer',
#  'black',
#  'French_bulldog',
#  'standard_poodle',
#  'cocker_spaniel',
#  'keeshond',
#  'Scotch_terrier',
#  'English_foxhound',
#  'giant_schnauzer',
#  'wire',
#  'Shetland_sheepdog',
#  'soft',
#  'Great_Dane',
#  'dingo',
#  'bull_mastiff',
#  'Irish_setter',
#  'standard_schnauzer',
#  'Cardigan',
#  'miniature_poodle',
#  'Mexican_hairless',
#  'Staffordshire_bullterrier',
#  'miniature_schnauzer',
#  'schipperke',
#  'vizsla',
#  'komondor',
#  'collie',
#  'Brabancon_griffon',
#  'kelpie',
#  'Walker_hound',
#  'Gordon_setter',
#  'German_shepherd',
#  'briard',
#  'flat',
#  'German_short',
#  'Rottweiler',
#  'Brittany_spaniel',
#  'Tibetan_mastiff',
#  'Chihuahua',
#  'borzoi',
#  'Appenzeller',
#  'toy_poodle',
#  'boxer',
#  'Sussex_spaniel',
#  'otterhound',
#  'curly',
#  'Doberman',
#  'Bouvier_des_Flandres',
#  'dhole',
#  'Welsh_springer_spaniel',
#  'affenpinscher',
#  'groenendael',
#  'Eskimo_dog',
#  'kuvasz',
#  'clumber',
#  'golden_retriever',
#  'malinois',
#  'Border_collie',
#  'Irish_water_spaniel',
#  'Pekinese',
#  'redbone']

# %%
print(f"The number of remaining pictures is {df_breeds.num_pictures.sum()}")

plt.figure(figsize=(10,30))
sns.barplot(x=df_breeds.num_pictures,
            y=df_breeds.index)
plt.xticks(rotation=0, fontsize=18)
plt.yticks(fontsize=10)
plt.xlabel('Number of pictures', fontsize=18)
plt.show()
# Out:
# The number of remaining pictures is 20580

# %% [markdown]
# ## 1.2 Cropping

# %%
import xml.etree.ElementTree as ET

def dog_breed_annotations(dog, breed):
    
    tree = ET.parse(annotations_dir + breed + '/' + dog)
    
    xmin = int(tree.getroot().findall('object')[0].find('bndbox').find('xmin').text)
    xmax = int(tree.getroot().findall('object')[0].find('bndbox').find('xmax').text)
    
    ymin = int(tree.getroot().findall('object')[0].find('bndbox').find('ymin').text)
    ymax = int(tree.getroot().findall('object')[0].find('bndbox').find('ymax').text)
   
    return xmin, xmax, ymin, ymax


def crop_image(breed, dog, img):
    
    xmin, xmax, ymin, ymax = dog_breed_annotations(dog, breed)
    crop_img = img[ymin:ymax, xmin:xmax, :]
    
    return crop_img

# %%
plt.figure(figsize=(20, 20))
for i in range(4):
    breed = np.random.choice(breed_names)
    dog   = np.random.choice(os.listdir(annotations_dir + breed))
    xmin, xmax, ymin, ymax = dog_breed_annotations(dog, breed)
    img      = plt.imread(images_dir + breed + '/' + dog + '.jpg')
    crop_img = crop_image(breed, dog, img)
    
    ## Plot image and anootations
    plt.subplot(421 + (i*2))
    plt.imshow(img)  
    plt.plot([xmin, xmax, xmax, xmin, xmin], [ymin, ymin, ymax, ymax, ymin])
    plt.title("{} {}".format(breed,img.shape))
    
    ## Plot cropped images    
    plt.subplot(422 + (i*2))
    plt.imshow(crop_img)
    plt.title("{}".format(crop_img.shape))

# %% [markdown]
# ### Ici on on découpe toutes les images du dataset pour avoir les chiens au centre de l'image

# %%
pwd
# Out:
# '/home/ahea/TRAVAIL/DDS/OCR/P06Images/Progs/final'

# %%
crop_dir = 'Data_all_cropped/'
if not os.path.exists(crop_dir):
    os.mkdir(crop_dir)
else:
    shutil.rmtree(crop_dir)

# %%
# if crop_dir not in os.listdir():
#     os.mkdir(crop_dir)
    
for breed_name in breed_names:
    os.mkdir(crop_dir + breed_name)
    
print('Created {} folders to store cropped images of the different breeds.'\
      .format(len(os.listdir(crop_dir))))
# Out:
# Created 120 folders to store cropped images of the different breeds.

# %%
from PIL import Image

for_all_start = time.time()

for breed in tqdm.tqdm(os.listdir(crop_dir), total=len(os.listdir(crop_dir))):
    for file in os.listdir(annotations_dir + breed):
        img = Image.open(images_dir + breed + '/' + file + '.jpg')
        xmin, xmax, ymin, ymax = dog_breed_annotations(file, breed)
        img = img.crop((xmin,ymin,xmax,ymax))
        img = img.convert('RGB')
        img.save(crop_dir + breed + '/' + file + '.jpg')
    breed_end = time.time()

for_all_end = time.time()
print(f"Total elapsed time is {for_all_end - for_all_start}")
# Out:
# 100%|██████████| 120/120 [00:38<00:00,  3.08it/s]
# Total elapsed time is 39.00894904136658

# %% [markdown]
# #### Show random image in cropped dir

# %%
r = np.random.choice(range(len(breed_names)))
rand_img = plt.imread(crop_dir + breed_names[r] + '/' + 
                      np.random.choice(os.listdir(crop_dir + breed_names[r])))

# %%
# Plot
plt.figure(figsize=(8,8))
plt.title("{} {}".format(breed_names[r],rand_img.shape))
plt.imshow(rand_img) 
plt.show()

# %% [raw]
# # import splitfolders
#
# # splitfolders.ratio('Data/data_cropped/', output="Data/splitted_data", seed=1337, ratio=(.8, 0.1,0.1))

# %% [markdown]
# ## 1.3 Sous-échantillon du dataset original

# %%
# new images_dir:
images_dir = crop_dir

# %% [markdown]
# ####  Create dir

# %%
sampl_path = 'Data_sample_B20_n0/'
if not os.path.exists(sampl_path):
    os.mkdir(sampl_path)
else:
    shutil.rmtree(sampl_path)

# %% [markdown]
# #### process...

# %%
nb_breed          = 20 #len(reduced_breed_names)

# list of random breeds
breedLists = list(np.arange(len(breed_names)))
breedLists = random.sample(breedLists,nb_breed)
breedNames = [breed_names[breed] for breed in breedLists] 

for breedName in breedNames:
    print(f"breedName {breedName} length is {len(os.listdir(images_dir + breedName))}")
    source_path = images_dir + breedName
    destin_path = sampl_path + breedName
    destination = shutil.copytree(source_path, destin_path)
# Out:
# breedName golden_retriever length is 150
# breedName Kerry_blue_terrier length is 179
# breedName Lakeland_terrier length is 197
# breedName Lhasa length is 186
# breedName Irish_setter length is 155
# breedName EntleBucher length is 202
# breedName Siberian_husky length is 192
# breedName Walker_hound length is 153
# breedName Great_Pyrenees length is 213
# breedName Border_collie length is 150
# breedName Scotch_terrier length is 158
# breedName malamute length is 178
# breedName Shetland_sheepdog length is 157
# breedName otterhound length is 151
# breedName malinois length is 150
# breedName bluetick length is 171
# breedName Sealyham_terrier length is 202
# breedName English_setter length is 161
# breedName affenpinscher length is 150
# breedName soft length is 156

# %%
# Count the number of classes (dogs breeds)
reduced_breed_names = os.listdir(sampl_path)
print("Number of breeds in dataset:", (len(reduced_breed_names)))
# Out:
# Number of breeds in dataset: 20

# %% [markdown]
# #### Show random image in data subset

# %%
check_dir = sampl_path # + 'train/'

# %%
# Choose random image
r = np.random.choice(range(len(reduced_breed_names)))
rand_img = plt.imread(check_dir + reduced_breed_names[r] + '/' + 
                      np.random.choice(os.listdir(check_dir + reduced_breed_names[r])))

# %%
# Plot
plt.figure(figsize=(8,8))
plt.title("{} {}".format(reduced_breed_names[r],rand_img.shape))
plt.imshow(rand_img) 
plt.show()
